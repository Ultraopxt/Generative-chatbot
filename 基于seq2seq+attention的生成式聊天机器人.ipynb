# %%
# !pip install jieba

# %%
! python3 'pre_process.py'

# %%
! python3 'model.py'

# %%
! python3 'train.py'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# After iters 27570: loss = 2.900; train bleu: 0.188, embAve: 0.369; test bleu: 0.156, embAve: 0.308; 492.805 qa/s; remaining time: 4055.153s;
# After iters 27580: loss = 3.005; train bleu: 0.177, embAve: 0.350; test bleu: 0.121, embAve: 0.256; 492.800 qa/s; remaining time: 4053.569s;
# After iters 27580: loss = 3.005; train bleu: 0.177, embAve: 0.350; test bleu: 0.121, embAve: 0.256; 492.800 qa/s; remaining time: 4053.569s;
# After iters 27590: loss = 2.738; train bleu: 0.259, embAve: 0.390; test bleu: 0.178, embAve: 0.345; 492.794 qa/s; remaining time: 4051.994s;
# After iters 27590: loss = 2.738; train bleu: 0.259, embAve: 0.390; test bleu: 0.178, embAve: 0.345; 492.794 qa/s; remaining time: 4051.994s;
# After iters 27600: loss = 2.033; train bleu: 0.161, embAve: 0.347; test bleu: 0.122, embAve: 0.261; 492.788 qa/s; remaining time: 4050.423s;
# ...

# %%
! python3 'test.py'

# %%
! python3 'demo.py'
# Out:
# Loading the model...
# Finished...
# 主人: 你是谁
# 小可爱:  我是人
#
# 主人: 天气怎么样
# 小可爱:  不知道是谁
#
# 主人: 吃了么
# 小可爱:  哦,吃了就好
#
# 主人: 不知道吃啥
# 小可爱:  你爱吃的东西可多了
#
# 主人: 想放假
# 小可爱:  问吧,听着呢
#
# 主人: 想家了
# 小可爱:  来了
#
# 主人: 哈哈
# 小可爱:  咯咯,我笑得比你好看
#
# 主人: 又不是想你
# 小可爱:  一定要多想哦,除了WC以外的时间都要想我
#
# 主人: 搞笑呢
# 小可爱:  U,,,,,
#
# 主人: 再见
# 小可爱:  88,要想我哦
#
# 主人: 锄禾日当午
# 小可爱:  世界上最好的
#
# 主人: 离离原上草
# 小可爱:  最近
#
# 主人: 工作好多
# 小可爱:  嗯啊,一起
#
# 主人: 你会啥
# 小可爱:  5.2..
#
# 主人: 你倒是很乐观
# 小可爱:  交学费没有
#
# 主人: 我也很乐观呀 干嘛交你学费
# 小可爱:  够了够了,不够再找你要
#
# 主人: 你还会花钱呢
# 小可爱:  好的
#
# 主人:
